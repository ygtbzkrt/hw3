# %%
import nsfg
import thinkstats2
import thinkplot
import numpy as np
resp = nsfg.ReadFemResp()

# %%
timesmar=resp['timesmar']

# %%
timesmar=timesmar.dropna()

# %%
jintendn=resp['jintendn']

# %%
jintendn=jintendn.dropna()

# %%
mean_t=timesmar.mean()

# %%
std_t=timesmar.std()

# %%
mean_t
# Out:
# 1.3870576829859429

# %%
std_t
# Out:
# 4.2971130232530834

# %%
mean_j=jintendn.mean()
mean_j
# Out:
# 2.7052556818181817

# %%
std_j=jintendn.std()
std_j
# Out:
# 9.710108051456988

# %%
prob_df=thinkstats2.NormalPdf(mean_t, std_t)

# %%
prob_df.Density(mean_t+std_t)
# Out:
# 0.056310067529003929

# %%
thinkplot.Pdf(prob_df,label="normal")
thinkplot.Config(xlabel='x', ylabel='prob_df')

# %%
prob_mf = prob_df.MakePmf()
thinkplot.Pmf(prob_mf, label='normalized')
thinkplot.Config(xlabel='x', ylabel='prob_mf')

# %%
pdfofj = thinkstats2.NormalPdf(mean_j, std_j)
pdfofj.Density(mean_j+std_j )
thinkplot.Pdf(pdfofj, label='normal') 
thinkplot.Config(xlabel='x', ylabel='prob_df of jintendn')

# %%
pmfofj = pdfofj.MakePmf()
thinkplot.Pmf(pmfofj, label='normalized')
thinkplot.Config(xlabel='x', ylabel='prob_mf of jintendn')

# %%
timesmarriage=resp['timesmar']
meanoftimesmarriage= timesmarriage.mean()
stdoftimesmarriage =timesmarriage.std()
pdf_marriage = thinkstats2.NormalPdf(meanoftimesmarriage, stdoftimesmarriage)
pdf_marriage.Density(meanoftimesmarriage+stdoftimesmarriage )
thinkplot.Pdf(pdf_marriage, label='normal')
thinkplot.Config(xlabel='x', ylabel='PDF of timesmarriage')

# %%
#We find mean and std of jintend and timesmarriage then we use this values for pmf and pdf of timesmarriage and jintend
#So pdf's are normal and pmf's are the normalize

# %%
def Jitter(values, jitter=0.5):
     """Jitters the values by adding a uniform variate in (-jitter, jitter).
    values: sequence
    jitter: scalar magnitude of jitter
    
    returns: new numpy array
    """
    n = len(values)
    return np.random.normal(0, jitter, n) + values
#https://github.com/donnemartin/data-science-ipython-notebooks/blob/master/scipy/thinkstats2.py
# Out:
#   File "<ipython-input-45-01a467e0bc4b>", line 8
#     n = len(values)
#                    ^
# IndentationError: unindent does not match any outer indentation level

# %%
timesmar = Jitter(timesmar,0.5)
jintendn = Jitter(jintendn, 1.4)
thinkplot.Scatter(timesmar, jintendn, alpha=1,s=1,color='black')
thinkplot.Config(xlabel='timesmar',
                 ylabel=' jintendn',
                 legend=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-ff56eef654b5> in <module>()
#       1 timesmar = Jitter(timesmar,0.5)
#       2 jintendn = Jitter(jintendn, 0.5)
# ----> 3 thinkplot.Scatter(timesmar, jintendn, alpha=1,s=1,color='black')
#       4 thinkplot.Config(xlabel='timesmar',
#       5                  ylabel=' jintendn',
#
# C:\Users\yigitbozkurt\Desktop\assg3\thinkplot.pyc in Scatter(xs, ys, **options)
#
# c:\python27\lib\site-packages\matplotlib\pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3433                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3434                          linewidths=linewidths, verts=verts,
# -> 3435                          edgecolors=edgecolors, data=data, **kwargs)
#    3436     finally:
#    3437         ax._hold = washold
#
# ...

# %%
clean = resp.dropna(subset=['timesmar', 'jintendn'])

# %%
bin = np.arange(-1,5, 1)

# %%
indices = np.digitize(clean.timesmar, bin)

# %%
grps = cleaned.groupby(indices)

# %%
mean_t = [group.timesmar.mean() for i, group in grps]

# %%
cdfs = [thinkstats2.Cdf(group.jintendn) for i, group in grps]
mean_t
# Out:
# [1.0, 2.0, 3.0, 4.0]

# %%
C_Colors = ["black","blue","yellow"] 
percent =[25, 50, 75] 
for i in range(len(percent)):
    jintendn_percentiles = [cdf.Percentile(percent[i]) for cdf in cdfs]
    label = '%dth' % percent[i]
    thinkplot.Plot(mean_timesmar, jintendn_percentiles, label=label,color=C_Colors[i])
    
thinkplot.Config(xlabel='timesmarriage',
                 ylabel='jintendn',
                 legend=True)
